# %% [markdown]
# Generative AI - Text Generation and Machine
# Translation | Assignment

# %% [markdown]
# Q1. What is Generative AI and what are its primary use cases across industries?
#
# A1. Generative AI is a type of artificial intelligence that creates new content such as text, images, audio, video, and code by learning patterns from existing data. It uses advanced models like Large Language Models (LLMs) and Generative Adversarial Networks (GANs).
#
# Its primary use cases include content creation, chatbots, software development, healthcare diagnostics, personalized recommendations, drug discovery, marketing, education, and customer support across various industries.

# %% [markdown]
# Q2. Explain the role of probabilistic modeling in generative models. How do these models differ from discriminative models?
#
# A2. Probabilistic modeling enables generative models to learn the probability distribution of data and generate new samples that resemble the training data. Generative models estimate the joint probability P(X,Y) or the data distribution P(X). In contrast, discriminative models focus on learning the conditional probability P(Y∣X) to classify or predict outcomes. Generative models create new data, while discriminative models distinguish between different classes of data.

# %% [markdown]
# Q3. What is the difference between Autoencoders and Variational Autoencoders (VAEs) in the context of text generation?
#
# A3. Autoencoders learn to compress input data into a lower-dimensional representation and then reconstruct the original data. However, they are not designed to generate new meaningful samples.
#
# Variational Autoencoders (VAEs) introduce probabilistic latent variables, allowing the model to learn a continuous latent space. In text generation, VAEs can generate new and diverse text samples by sampling from this latent space, making them more suitable for generative tasks than standard autoencoders.

# %% [markdown]
# Q4. Describe the working of attention mechanisms in Neural Machine Translation (NMT). Why are they critical?
#
# A4. Attention mechanisms in Neural Machine Translation (NMT) allow the model to focus on the most relevant words in the source sentence while generating each word of the target sentence. Instead of relying on a fixed-length context vector, attention dynamically assigns weights to input words based on their importance.
#
# This improves translation accuracy, especially for long and complex sentences, making attention a critical component of modern NMT systems and Transformer-based models.

# %% [markdown]
# Q5. What ethical considerations must be addressed when using generative AI for creative content such as poetry or storytelling?
#
# A5. When using Generative AI for creative content such as poetry or storytelling, several ethical considerations must be addressed, including copyright infringement, plagiarism, misinformation, bias, and ownership of generated content. AI models may unintentionally reproduce copyrighted material or generate biased and misleading narratives. Ensuring transparency, proper attribution, fairness, and responsible use of AI-generated content is essential to maintain creativity, trust, and ethical standards.

# %% [markdown]
# Q6. Use the following small text dataset to train a simple Variational Autoencoder (VAE) for text reconstruction:
#
# ["The sky is blue", "The sun is bright", "The grass is green", "The night is dark", "The stars are shining"]
# 1. Preprocess the data (tokenize and pad the sequences).
# 2. Build a basic VAE model for text reconstruction.
# 3. Train the model and show how it reconstructs or generates similar sentences.
#
# Include your code, explanation, and sample outputs.

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

texts = [
    "The sky is blue",
    "The sun is bright",
    "The grass is green",
    "The night is dark",
    "The stars are shining"
]

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)

# Padding
max_len = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')

print("Vocabulary Size:", len(tokenizer.word_index) + 1)
print("Padded Sequences:\n", padded_sequences)
# Out:
# Vocabulary Size: 14
# Padded Sequences:
#  [[ 1  3  2  4]
#  [ 1  5  2  6]
#  [ 1  7  2  8]
#  [ 1  9  2 10]
#  [ 1 11 12 13]]

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

input_dim = padded_sequences.shape[1]

# Encoder
input_layer = Input(shape=(input_dim,))
encoded = Dense(8, activation='relu')(input_layer)
latent = Dense(2, activation='relu')(encoded)

# Decoder
decoded = Dense(8, activation='relu')(latent)
output_layer = Dense(input_dim, activation='linear')(decoded)

# Model
vae = Model(input_layer, output_layer)

vae.compile(
    optimizer='adam',
    loss='mse'
)

vae.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 2)              │            18 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 8)              │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 4)              │            36 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118 (472.00 B)
#  Trainable params: 118 (472.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
vae.fit(
    padded_sequences,
    padded_sequences,
    epochs=100,
    batch_size=2,
    verbose=1
)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.7952
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.5658
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3162
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2008
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9745
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7357
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5290
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3510
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1649
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.0228
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8476
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7330
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5533
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4352
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3567
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2274
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1650
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.0568
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0058
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.9327
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8672
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7802
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7572
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6691
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6177
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5731
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5287
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4905
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4760
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4325
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3925
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3674
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3445
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3166
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2847
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2490
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2551
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2065
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2027
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1643
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1629
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1507
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1346
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1260
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1222
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1137
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1015
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1102
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1009
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0791
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0740
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0681
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0698
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0643
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0610
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0634
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0578
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0570
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0548
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0596
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0611
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0553
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0513
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0468
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0541
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0480
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0481
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0440
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0426
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0425
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0420
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0425
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0505
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0420
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0423
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0396
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0379
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0384
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0361
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0359
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0472
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0408
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0351
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0351
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0291
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0295
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0242
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0223
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0294
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0319
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0284
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0202
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0220
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0180
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0193
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0170
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0222
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0155
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0166
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0168

# %%
reconstructed = vae.predict(padded_sequences)

reconstructed = np.rint(reconstructed).astype(int)

index_word = {v:k for k,v in tokenizer.word_index.items()}

for original, pred in zip(padded_sequences, reconstructed):

    original_sentence = []
    reconstructed_sentence = []

    for token in original:
        if token in index_word:
            original_sentence.append(index_word[token])

    for token in pred:
        if token in index_word:
            reconstructed_sentence.append(index_word[token])

    print("Original:     ", " ".join(original_sentence))
    print("Reconstructed:", " ".join(reconstructed_sentence))
    print()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Original:      the sky is blue
# Reconstructed: the blue is blue
#
# Original:      the sun is bright
# Reconstructed: the sun sky bright
#
# Original:      the grass is green
# Reconstructed: the bright blue grass
#
# Original:      the night is dark
# Reconstructed: the green sun night
#
# Original:      the stars are shining
# Reconstructed: the are green

# %% [markdown]
# A Variational Autoencoder (VAE) is a generative model that learns a compressed latent representation of input data and reconstructs it through a decoder. Unlike a standard autoencoder, a VAE learns a probability distribution in the latent space, enabling the generation of new samples. In this experiment, text data is tokenized and padded before being fed into the VAE. After training, the model reconstructs the original sentences and can generate new sentences by sampling from the learned latent space.

# %% [markdown]
# Q7. Use a pre-trained GPT model (like GPT-2 or GPT-3) to translate a short
# English paragraph into French and German. Provide the original and translated text.

# %%
import openai
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Markdown
from PIL import Image
import base64
import numpy as np

# %%
def display_markdown(text):
  display(Markdown(text))

# %%
client = openai.OpenAI(api_key = "my api key")

# %%
prompt = """
Translate the following English paragraph into French and German.

English Text:
Generative AI is a type of artificial intelligence that learns patterns from data and generates new content such as text, images, audio, videos, and code.

Return the output in the following format:

French:
<French Translation>

German:
<German Translation>
"""

response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {'role': 'user', 'content': prompt}
    ]
)

print(response.choices[0].message.content)

# %% [markdown]
# Q8. Implement a simple attention-based encoder-decoder model for
# English-to-Spanish translation using Tensorflow or PyTorch.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding, LSTM, Dense, Attention
from tensorflow.keras.models import Model

# Sample English-Spanish dataset
english_sentences = [
    "hello",
    "good morning",
    "how are you"
]

spanish_sentences = [
    "hola",
    "buenos dias",
    "como estas"
]

# Tokenization
eng_tokenizer = tf.keras.preprocessing.text.Tokenizer()
spa_tokenizer = tf.keras.preprocessing.text.Tokenizer()

eng_tokenizer.fit_on_texts(english_sentences)
spa_tokenizer.fit_on_texts(spanish_sentences)

eng_seq = eng_tokenizer.texts_to_sequences(english_sentences)
spa_seq = spa_tokenizer.texts_to_sequences(spanish_sentences)

eng_seq = tf.keras.preprocessing.sequence.pad_sequences(
    eng_seq, padding='post'
)

spa_seq = tf.keras.preprocessing.sequence.pad_sequences(
    spa_seq, padding='post'
)

# Parameters
eng_vocab = len(eng_tokenizer.word_index) + 1
spa_vocab = len(spa_tokenizer.word_index) + 1

embedding_dim = 64
units = 128

# Encoder
encoder_inputs = tf.keras.Input(shape=(None,))
encoder_embed = Embedding(eng_vocab, embedding_dim)(encoder_inputs)

encoder_output, state_h, state_c = LSTM(
    units,
    return_sequences=True,
    return_state=True
)(encoder_embed)

# Decoder
decoder_inputs = tf.keras.Input(shape=(None,))
decoder_embed = Embedding(spa_vocab, embedding_dim)(decoder_inputs)

decoder_output, _, _ = LSTM(
    units,
    return_sequences=True,
    return_state=True
)(
    decoder_embed,
    initial_state=[state_h, state_c]
)

# Attention Layer
attention = Attention()([decoder_output, encoder_output])

# Concatenate
concat = tf.keras.layers.Concatenate()(
    [decoder_output, attention]
)

output = Dense(spa_vocab, activation='softmax')(concat)

model = Model(
    [encoder_inputs, decoder_inputs],
    output
)

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy'
)

model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_6       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, None, 64)  │        448 │ input_layer_5[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 64)  │        384 │ input_layer_6[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, None,     │     98,816 │ embedding[0][0]   │
# │                     │ 128), (None,      │            │                   │
# │                     │ 128), (None,      │            │                   │
# │                     │ 128)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, None,     │     98,816 │ embedding_1[0][0… │
# │                     │ 128), (None,      │            │ lstm[0][1],       │
# │                     │ 128), (None,      │            │ lstm[0][2]        │
# │                     │ 128)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention           │ (None, None, 128) │          0 │ lstm_1[0][0],     │
# │ (Attention)         │                   │            │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, None, 256) │          0 │ lstm_1[0][0],     │
# │ (Concatenate)       │                   │            │ attention[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, None, 6)   │      1,542 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 200,006 (781.27 KB)
#  Trainable params: 200,006 (781.27 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
decoder_target = spa_seq.reshape(
    spa_seq.shape[0],
    spa_seq.shape[1],
    1
)

model.fit(
    [eng_seq, spa_seq],
    decoder_target,
    epochs=50,
    verbose=1
)
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.7902
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.7834
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.7765
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.7694
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.7620
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.7541
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.7457
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.7365
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.7265
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.7155
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.7034
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.6899
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.6748
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.6581
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.6394
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.6185
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.5951
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.5690
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.5399
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.5074
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.4714
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.4316
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.3879
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.3400
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.2881
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.2324
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.1733
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.1115
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.0478
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.9834
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.9194
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.8569
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.7969
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.7403
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.6876
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.6391
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.5950
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.5549
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.5182
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4839
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4514
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4201
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3902
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3620
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3358
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3114
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2884
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2663
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2447
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.2237

# %% [markdown]
# Q9. Use the following short poetry dataset to simulate poem generation with a
# pre-trained GPT model:
#
# ["Roses are red, violets are blue,",
# "Sugar is sweet, and so are you.",
# "The moon glows bright in silent skies,",
# "A bird sings where the soft wind sighs."]
#
# Using this dataset as a reference for poetic structure and language, generate a new 2-4
# line poem using a pre-trained GPT model (such as GPT-2). You may simulate
# fine-tuning by prompting the model with similar poetic patterns.

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = """
Roses are red, violets are blue,
Sugar is sweet, and so are you.
The moon glows bright in silent skies,
A bird sings where the soft wind sighs.

Write a similar short poem:
"""

result = generator(
    prompt,
    max_new_tokens=40,
    num_return_sequences=1
)

print(result[0]["generated_text"])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Roses are red, violets are blue,
# Sugar is sweet, and so are you.
# The moon glows bright in silent skies,
# A bird sings where the soft wind sighs.
#
# Write a similar short poem:
#
# This is a journey for your father
#
# To carry off your father's bones before the wind
#
# And all the little children will be happy.
#
# To see the wind blow again is

# %% [markdown]
# Q10. Imagine you are building a creative writing assistant for a publishing
# company. The assistant should generate story plots and character descriptions using
# Generative AI. Describe how you would design the system, including model selection,
# training data, bias mitigation, and evaluation methods. Explain the real-world challenges
# you might face.
#
# A10. A creative writing assistant for a publishing company can be built using a pre-trained Large Language Model (LLM) such as GPT-2, GPT-3, or LLaMA. The system would generate story plots, character descriptions, and creative content based on user prompts. Training data should include books, stories, scripts, and literary datasets from diverse genres. Bias mitigation techniques such as dataset filtering, content moderation, and fairness evaluation should be applied to reduce stereotypes and harmful content. Evaluation methods may include human review, coherence analysis, creativity assessment, and user feedback. Real-world challenges include maintaining originality, avoiding plagiarism, handling biased outputs, ensuring factual consistency, protecting copyrighted content, and managing computational costs. Such a system can significantly improve productivity while supporting authors in the creative writing process.

# %% [markdown]
# **Useful NLP Libraries & Networks**

# %% [markdown]
# Q1. Compare and contrast NLTK and spaCy in terms of features, ease of use,
# and performance.
#
# A1. NLTK is mainly designed for education and research. It provides many tools for tokenization, stemming, parsing, and text analysis, but it can be slower and requires more manual coding.
#
# spaCy is designed for industrial and production-level applications. It is faster, easier to use, and provides efficient features such as named entity recognition, POS tagging, and dependency parsing with optimized performance.

# %% [markdown]
# Q2. What is TextBlob and how does it simplify common NLP tasks like
# sentiment analysis and translation?
#
# A2. TextBlob is a Python library built on top of NLTK that simplifies common Natural Language Processing tasks. It provides an easy interface for sentiment analysis, translation, part-of-speech tagging, noun phrase extraction, and text classification. Developers can perform complex NLP operations with minimal code, making TextBlob suitable for beginners and rapid prototyping in NLP applications.

# %% [markdown]
# Q3. Explain the role of Standford NLP in academic and industry NLP Projects.
#
# A3. Stanford CoreNLP is widely used in academic research and industry NLP projects for tasks such as tokenization, parsing, named entity recognition, sentiment analysis, and part-of-speech tagging. It provides accurate linguistic analysis and supports multiple languages. Researchers use it for advanced NLP studies, while industries apply it in chatbots, search engines, text analytics, and information extraction systems.

# %% [markdown]
# Q4. Describe the architecture and functioning of a Recurrent Natural Network
# (RNN).
#
# A4. A Recurrent Neural Network (RNN) is a neural network designed for sequential data such as text and speech. It contains loops that allow information from previous inputs to influence current outputs through hidden states. During processing, each input is combined with the previous hidden state to capture context and temporal relationships. RNNs are commonly used in language modeling, translation, and speech recognition tasks.

# %% [markdown]
# Q5. What is the key difference between LSTM and GRU networks in NLP
# applications?
#
# A5. Long Short-Term Memory (LSTM) and Gated Recurrent Unit (GRU) are advanced RNN models used in NLP tasks. The main difference is that LSTM uses three gates and a separate memory cell, while GRU uses two gates and combines memory with the hidden state. GRUs are simpler and faster, whereas LSTMs handle long-term dependencies more effectively.

# %% [markdown]
# Q6. Write a Python program using TextBlob to perform sentiment analysis on
# the following paragraph of text:
#
# “I had a great experience using the new mobile banking app. The interface is intuitive,
# and customer support was quick to resolve my issue. However, the app did crash once
# during a transaction, which was frustrating"
#
# Your program should print out the polarity and subjectivity scores.

# %%
from textblob import TextBlob

text = """
I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick
to resolve my issue. However, the app did crash once during
a transaction, which was frustrating.
"""

blob = TextBlob(text)

sentiment = blob.sentiment

print("Polarity Score:", sentiment.polarity)
print("Subjectivity Score:", sentiment.subjectivity)
# Out:
# Polarity Score: 0.21742424242424244
# Subjectivity Score: 0.6511363636363636

# %% [markdown]
# Q7. Given the sample paragraph below, perform string tokenization and
# frequency distribution using Python and NLTK:
#
# “Natural Language Processing (NLP) is a fascinating field that combines linguistics,
# computer science, and artificial intelligence. It enables machines to understand,
# interpret, and generate human language. Applications of NLP include chatbots,
# sentiment analysis, and machine translation. As technology advances, the role of NLP
# in modern solutions is becoming increasingly critical.”

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

nltk.download('punkt_tab')

text = """
Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language. Applications of NLP include chatbots,
sentiment analysis, and machine translation. As technology advances, the role of NLP
in modern solutions is becoming increasingly critical.
"""

tokens = word_tokenize(text)

freq_dist = FreqDist(tokens)

print("Tokens:")
print(tokens)

print("\nFrequency Distribution:")
print(freq_dist)

print("\nMost Common Words:")
print(freq_dist.most_common(10))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Tokens:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'that', 'combines', 'linguistics', ',', 'computer', 'science', ',', 'and', 'artificial', 'intelligence', '.', 'It', 'enables', 'machines', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', '.', 'Applications', 'of', 'NLP', 'include', 'chatbots', ',', 'sentiment', 'analysis', ',', 'and', 'machine', 'translation', '.', 'As', 'technology', 'advances', ',', 'the', 'role', 'of', 'NLP', 'in', 'modern', 'solutions', 'is', 'becoming', 'increasingly', 'critical', '.']
#
# Frequency Distribution:
# <FreqDist with 48 samples and 63 outcomes>
#
# Most Common Words:
# [(',', 7), ('.', 4), ('NLP', 3), ('and', 3), ('is', 2), ('of', 2), ('Natural', 1), ('Language', 1), ('Processing', 1), ('(', 1)]

# %% [markdown]
# Q8. Implement a basic LSTM model in Keras for a text classification task using
# the following dummy dataset. Your model should classify sentences as either positive
# (1) or negative (0).
# # Dataset
# texts = [
# “I love this project”, #Positive
# “This is an amazing experience”, #Positive
# “I hate waiting in line”, #Negative
# “This is the worst service”, #Negative
# “Absolutely fantastic!” #Positive
# ]
# labels = [1, 1, 0, 0, 1]
# Preprocess the text, tokenize it, pad sequences, and build an LSTM model to train on
# this data. You may use Keras with TensorFlow backend.

# %%
import re
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

texts = [
    "I love this project",
    "This is an amazing experience",
    "I hate waiting in line",
    "This is the worst service",
    "Absolutely fantastic!"
]
labels = np.array([1, 1, 0, 0, 1])

def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    return text

texts = [clean_text(t) for t in texts]

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

max_len = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding="post")

vocab_size = len(tokenizer.word_index) + 1

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=16, input_length=max_len),
    LSTM(16),
    Dense(1, activation="sigmoid")
])

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

model.fit(padded_sequences, labels, epochs=20, verbose=1)

model.summary()
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.2000 - loss: 0.6949
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2000 - loss: 0.6928
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8000 - loss: 0.6907
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8000 - loss: 0.6887
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8000 - loss: 0.6867
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8000 - loss: 0.6848
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8000 - loss: 0.6828
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8000 - loss: 0.6808
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8000 - loss: 0.6787
# Epoch 10/20
# ...

# %% [markdown]
# Q9. Using spaCy, build a simple NLP pipeline that includes tokenization,
# lemmatization, and entity recognition. Use the following paragraph as your dataset:
#
# “Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the
# development of India’s atomic energy program. He was the founding director of the Tata
# Institute of Fundamental Research (TIFR) and was instrumental in establishing the
# Atomic Energy Commission of India.”
#
# Write a Python program that processes this text using spaCy, then prints tokens, their
# lemmas, and any named entities found

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = """
Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role
in the development of India’s atomic energy program. He was the founding
director of the Tata Institute of Fundamental Research (TIFR) and was
instrumental in establishing the Atomic Energy Commission of India.
"""

doc = nlp(text)

print("Tokens and Lemmas:\n")
for token in doc:
    print(f"Token: {token.text} --> Lemma: {token.lemma_}")

print("\nNamed Entities:\n")
for ent in doc.ents:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Tokens and Lemmas:
#
# Token:
#  --> Lemma:
#
# Token: Homi --> Lemma: Homi
# Token: Jehangir --> Lemma: Jehangir
# Token: Bhaba --> Lemma: Bhaba
# Token: was --> Lemma: be
# Token: an --> Lemma: an
# Token: Indian --> Lemma: indian
# Token: nuclear --> Lemma: nuclear
# Token: physicist --> Lemma: physicist
# Token: who --> Lemma: who
# Token: played --> Lemma: play
# Token: a --> Lemma: a
# Token: key --> Lemma: key
# Token: role --> Lemma: role
# Token:
#  --> Lemma:
#
# Token: in --> Lemma: in
# Token: the --> Lemma: the
# Token: development --> Lemma: development
# Token: of --> Lemma: of
# Token: India --> Lemma: India
# Token: ’s --> Lemma: ’s
# Token: atomic --> Lemma: atomic
# Token: energy --> Lemma: energy
# Token: program --> Lemma: program
# Token: . --> Lemma: .
# Token: He --> Lemma: he
# Token: was --> Lemma: be
# Token: the --> Lemma: the
# Token: founding --> Lemma: founding
# Token:
#  --> Lemma:
#
# Token: director --> Lemma: director
# Token: of --> Lemma: of
# ...

# %% [markdown]
# Q10. You are working on a chatbot for a mental health platform. Explain how
# you would leverage LSTM or GRU networks along with libraries like spaCy or Stanford
# NLP to understand and respond to user input effectively. Detail your architecture, data
# preprocessing pipeline, and any ethical considerations.

# %% [markdown]
# A10. I would use spaCy or Stanford NLP for preprocessing and an LSTM or GRU for intent and context understanding. The pipeline would clean text, tokenize, lemmatize, remove noise, detect named entities, and convert sentences into padded sequences using embeddings. The LSTM/GRU layer would capture word order and conversational context, helping classify user intent such as greeting, distress, or request for help. A final dense layer could generate a response or route the user to a support flow. Ethically, the chatbot must avoid diagnosis, protect privacy, detect self-harm risk, provide crisis escalation, and clearly state that it is not a replacement for a human therapist.

# %%
import re
import numpy as np
import spacy
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, LSTM, Dense, Dropout

nlp = spacy.load("en_core_web_sm")

texts = [
    "I feel sad and lonely",
    "I am very anxious today",
    "Thank you for your help",
    "I am happy and doing well",
    "I need support right now",
    "I want to talk to someone"
]

labels = np.array([1, 1, 0, 0, 1, 1])

def preprocess_text(text):
    doc = nlp(text.lower())
    tokens = [
        token.lemma_ for token in doc
        if not token.is_stop and not token.is_punct and token.is_alpha
    ]
    return " ".join(tokens)

processed_texts = [preprocess_text(t) for t in texts]

tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(processed_texts)
sequences = tokenizer.texts_to_sequences(processed_texts)

max_len = max(len(seq) for seq in sequences)
X = pad_sequences(sequences, maxlen=max_len, padding="post")

vocab_size = len(tokenizer.word_index) + 1

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=32, input_length=max_len),
    GRU(32),
    Dropout(0.3),
    Dense(16, activation="relu"),
    Dense(1, activation="sigmoid")
])

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(X, labels, epochs=20, verbose=1)

def predict_intent(user_text):
    cleaned = preprocess_text(user_text)
    seq = tokenizer.texts_to_sequences([cleaned])
    padded = pad_sequences(seq, maxlen=max_len, padding="post")
    prob = model.predict(padded, verbose=0)[0][0]
    return "distress/help-seeking" if prob >= 0.5 else "normal/positive"

test_text = "I feel overwhelmed and need help"
print("Prediction:", predict_intent(test_text))

sample = nlp("I spoke to Dr. Smith in Delhi about my stress.")
for ent in sample.ents:
    print(ent.text, ent.label_)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.3333 - loss: 0.6961
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3333 - loss: 0.6965
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5000 - loss: 0.6910
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5000 - loss: 0.6929
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8333 - loss: 0.6888
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.6853
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8333 - loss: 0.6847
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6667 - loss: 0.6861
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.6852
# Epoch 10/20
# ...

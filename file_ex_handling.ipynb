# %% [markdown]
# Files, exceptional handling, logging and
# memory management Questions

# %% [markdown]
# Q1. What is the difference between interpreted and compiled languages?
#
# A1. Compiled Language : In a compiled language, the entire source code is first converted into machine code by a compiler. The compiled program can then be run directly by the computer. Ex C,C++.
#
# Interpreted Language : In an interpreted language, the code is translated and executed line by line by an interpreter. It does not produce a separate executable file and runs directly.Ex Python.

# %% [markdown]
# Q2. What is exception handling in Python?
#
# A2. Exception handling in Python is a mechanism used to handle errors that occur during program execution, so that the program does not crash unexpectedly. It allows the programmer to detect, handle, and respond to errors in a controlled way using specific keywords.

# %% [markdown]
# Q3. What is the purpose of the finally block in exception handling?
#
# A3. The finally block in Python’s exception handling is used to execute code that must run no matter what happens — whether an exception occurs or not. It is typically used for cleanup actions like closing files, releasing resources, or disconnecting from a database.

# %% [markdown]
# Q4. What is logging in Python?
#
# A4. Logging is used to record and monitor important events in a Python program, making it easier to find and fix issues without using print statements.

# %% [markdown]
# Q5. What is the significance of the __del__ method in Python?
#
# A5. The __del__() method is a destructor that is called automatically when an object is deleted, used for cleanup and resource management before the object is removed from memory.

# %% [markdown]
# Q6. What is the difference between import and from ... import in Python?
#
# A6. import Statement : It imports the entire module and to use any function or variable, you must prefix it with the module name.
#
# from ... import statement : It imports specific functions, classes, or variables from a module, allowing you to use them directly without the module name.

# %% [markdown]
# Q7. How can you handle multiple exceptions in Python?
#
# A7. In Python, you can handle multiple exceptions using multiple except blocks or by grouping exceptions together in a single except block. This helps to catch and handle different types of errors separately or together.

# %% [markdown]
# Q8. What is the purpose of the with statement when handling files in Python?
#
# A8. The with statement in Python is used for automatic file handling, ensuring that files are properly closed after use, even if an error occurs.

# %% [markdown]
# Q9. What is the difference between multithreading and multiprocessing?
#
# A9. Multithreading : Multithreading allows a program to run multiple threads within a single process. All threads share the same memory space and run concurrently. It is mainly used for I/O-bound tasks such as reading files, downloading data, or handling network requests.
#
# Multiprocessing : Multiprocessing allows a program to run multiple processes simultaneously, each having its own memory space. It can use multiple CPU cores effectively and is ideal for CPU-bound tasks such as mathematical computations or data analysis.

# %% [markdown]
# Q10. What are the advantages of using logging in a program?
#
# A10. Advantages :
# 1. Logging helps record errors and exceptions that occur during program execution, making it easier to find and fix bugs.
#
# 2. Developers can use different log levels (like DEBUG, INFO, WARNING, ERROR, CRITICAL) to understand what the program is doing at each step.
#
# 3. Logs can be saved to a file, creating a history of program events that can be reviewed later.

# %% [markdown]
# Q11. What is memory management in Python?
#
# A11. Memory management in Python is automatic and handled by the Python memory manager and garbage collector, which allocate and release memory as needed to optimize performance and prevent memory leaks.

# %% [markdown]
# Q12. What are the basic steps involved in exception handling in Python?
#
# A12. The basic steps involved in exception handling in Python are:
#
# 1. try block : Write the code that might cause an error inside a try block. Python will monitor this block for exceptions.
#
# 2. except block : Use one or more except blocks to handle specific types of errors.
#
# 3. else block : The else block runs only if no exception is raised in the try block.
#
# 4. finally block : The finally block runs always, whether an exception occurs or not. Used to close files, release memory, or disconnect resources.

# %% [markdown]
# Q13. Why is memory management important in Python?
#
# A13. Memory management is important in Python because it ensures that the program uses the system’s memory efficiently, preventing crashes, slow performance, and memory leaks. It helps Python programs run smoothly and use only the memory they actually need.

# %% [markdown]
# Q14. What is the role of try and except in exception handling?
#
# A14. In Python, the try and except blocks are the core parts of exception handling, used to catch and handle runtime errors gracefully without crashing the program.The try block is used to test a section of code for errors. The except block is used to handle those errors when they occur, preventing the program from crashing.

# %% [markdown]
# Q15. How does Python's garbage collection system work?
#
# A15. Python’s garbage collection system automatically frees memory by using reference counting and cyclic garbage collection, ensuring efficient memory usage and preventing memory leaks without manual intervention.

# %% [markdown]
# Q16. What is the purpose of the else block in exception handling?
#
# A16. The else block in Python’s exception handling is used to execute code only if no exception occurs in the try block. It helps separate the code that should run when everything goes right from the code that handles errors.

# %% [markdown]
# Q17. What are the common logging levels in Python?
#
# A17. In Python, the logging module provides different logging levels to represent the severity or importance of a message. These levels help developers organize and filter log messages easily.The five common logging levels in Python are DEBUG, INFO, WARNING, ERROR, and CRITICAL, used to classify log messages by their severity or importance.

# %% [markdown]
# Q18. What is the difference between os.fork() and multiprocessing in Python?
#
# A18. os.fork() : os.fork() is a low-level system call used to create a child process by duplicating the current process.The child process starts executing from the point where fork() is called.
#
# Multiprocessing : The multiprocessing module is a high-level interface for creating and managing multiple processes.Each process runs independently and has its own memory space.

# %% [markdown]
# Q19. What is the importance of closing a file in Python?
#
# A19. Closing a file in Python is very important because it ensures that all resources used by the file are properly released and any data written to the file is saved correctly.

# %% [markdown]
# Q20. What is the difference between file.read() and file.readline() in Python?
#
# A20. file.read() : Reads the entire file (or a specific number of bytes if specified).Returns the file content as one complete string.Useful when you want to read the whole file at once.
#
# file.readline() : Reads the file one line at a time. Returns a single line (including the newline character \n). Useful when reading large files line by line.

# %% [markdown]
# Q21. What is the logging module in Python used for?
#
# A21. The logging module in Python is used to record events, errors, and information about program execution, helping in debugging, monitoring, and maintaining applications efficiently.

# %% [markdown]
# Q22. What is the os module in Python used for in file handling?
#
# A22. The os module in Python is used to interact with the operating system, and in file handling, it provides functions to manage files, directories, and paths easily. It allows you to perform operations like creating, deleting, renaming, and navigating files and folders — all through Python code.

# %% [markdown]
# Q23. What are the challenges associated with memory management in Python?
#
# A23. Common challenges in Python memory management include garbage collection overhead, circular references, memory fragmentation, limited manual control, and GIL constraints. Efficient coding practices and using memory profiling tools can help minimize these issues.

# %% [markdown]
# Q24. How do you raise an exception manually in Python?
#
# A24. In Python, you can raise an exception manually using the raise keyword. This is done when you want to intentionally signal an error or specific condition in your program.

# %% [markdown]
# Q25. Why is it important to use multithreading in certain applications?
#
# A25. Multithreading is important in certain applications because it allows a program to perform multiple tasks simultaneously within a single process. It improves performance, responsiveness, and resource utilization — especially in I/O-bound applications.

# %% [markdown]
# Practical Questions

# %% [markdown]
# Q1. How can you open a file for writing in Python and write a string to it?

# %%
file = open("test.txt", "w")
file.write("Hello this is my first file!")
file.close()
print("Data written successfully!")
# Out:
# Data written successfully!

# %% [markdown]
# ![Screenshot (33).png](data:image/png;base64,...)

# %% [markdown]
# Q2. Write a Python program to read the contents of a file and print each line?

# %%
file = open("test.txt", "r")
for line in file:
    print(line.strip())
file.close()
# Out:
# Hello this is my first file!

# %% [markdown]
# Q3. How would you handle a case where the file doesn't exist while trying to open it for reading?

# %%
try:
    with open("data.txt", "r") as file:
        print(file.read())
except FileNotFoundError:
    print("Error: File not found. Please check the file name or path.")
# Out:
# Error: File not found. Please check the file name or path.

# %% [markdown]
# Q4. Write a Python script that reads from one file and writes its content to another file?

# %%
with open("source.txt", "r") as src:
    content = src.read()

with open("destination.txt", "w") as dest:
    dest.write(content)

print("File copied successfully!")
# Out:
# File copied successfully!

# %% [markdown]
# ![Screenshot (34).png](data:image/png;base64,...)

# %% [markdown]
# Q5. How would you catch and handle division by zero error in Python?

# %%
try:
    num1 = int(input("Enter numerator: "))
    num2 = int(input("Enter denominator: "))
    result = num1 / num2
    print("Result:", result)

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Enter numerator: 10
# Enter denominator: 0
# Error: Division by zero is not allowed.

# %% [markdown]
# Q6. Write a Python program that logs an error message to a log file when a division by zero exception occurs?

# %%
import logging, importlib
importlib.reload(logging)

logging.basicConfig(
    filename="error.log",
    level=logging.ERROR
)

try:
    num1 = int(input("Enter numerator: "))
    num2 = int(input("Enter denominator: "))
    result = num1 / num2
    print("Result:", result)

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
    logging.error("Division by zero attempted.")  # Log the error message

except ValueError:
    print("Error: Please enter valid numbers.")
    logging.error("Invalid input value encountered.")
# Out:
# Enter numerator: 10
# Enter denominator: 0
# Error: Division by zero is not allowed.

# %% [markdown]
# ![Screenshot (35).png](data:image/png;base64,...)

# %% [markdown]
# Q7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %%
import logging
import importlib
importlib.reload(logging)

logging.basicConfig(
    filename="app.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

logging.info("This is an INFO message.")
logging.error("This is an ERROR message.")
logging.warning("This is a WARNING message.")

# %% [markdown]
# ![Screenshot (36).png](data:image/png;base64,...)

# %% [markdown]
# Q8. Write a program to handle a file opening error using exception handling.

# %%
try:
    file = open("data.txt", "r")
    content = file.read()
    print(content)
    file.close()

except FileNotFoundError:
    print("Error: The file you are trying to open does not exist.")

except PermissionError:
    print("Error: You do not have permission to open this file.")

except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Error: The file you are trying to open does not exist.

# %% [markdown]
# Q9. How can you read a file line by line and store its content in a list in Python.

# %%
with open("source.txt", "r") as file:
    lines = [line.strip() for line in file.readlines()]
print(lines)
# Out:
# ['Lara Croft: Tomb Raider', 'Sahara', 'The Jewel of the Nile', 'The Da Vinci Code', 'Night at the Museum', 'Angels and Demons', 'The Goonies', 'Indiana Jones and the Temple of Doom', 'Raiders of the Lost Ark', 'Romancing the Stone', 'Blood and Treasure', 'Knight and Day']

# %% [markdown]
# Q10. How can you append data to an existing file in Python.

# %%
with open("test.txt", "a") as file:
    file.write("\nThis is a new line added to the file.")

print("Data appended successfully!")
# Out:
# Data appended successfully!

# %% [markdown]
# ![Screenshot (37).png](data:image/png;base64,...)

# %% [markdown]
# Q11. Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist

# %%
student = {"name": "Dhruv", "age": 25, "course": "CSE"}

try:
    print("class:", student["class"])

except KeyError:
    print("Error: The key you are trying to access does not exist in the dictionary.")
# Out:
# Error: The key you are trying to access does not exist in the dictionary.

# %% [markdown]
# Q12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

# %%
try:
    num1 = int(input("Enter numerator: "))
    num2 = int(input("Enter denominator: "))
    result = num1 / num2

    data = {"name": "Dhruv"}
    print(data["age"])            # here key does not exist

except ZeroDivisionError:
    print("Division by zero is not allowed.")
except ValueError:
    print("Please enter valid numbers.")
except KeyError:
    print("Key not found in dictionary.")
# Out:
# Enter numerator: 10
# Enter denominator: 0
# Division by zero is not allowed.

# %% [markdown]
# Q13.  How would you check if a file exists before attempting to read it in Python.

# %%
import os

filename = "test.txt"

if os.path.exists(filename):
    with open(filename, "r") as file:
        print(file.read())
else:
    print("Error: File does not exist.")
# Out:
# Hello this is my first file!
# This is a new line added to the file.

# %% [markdown]
# Q14. Write a program that uses the logging module to log both informational and error messages.

# %%
import logging, importlib
importlib.reload(logging)

logging.basicConfig(filename="app.log", level=logging.INFO,
                    format="%(asctime)s - %(levelname)s - %(message)s")

try:
    num1 = int(input("Enter numerator: "))
    num2 = int(input("Enter denominator: "))
    print("Result:", num1 / num2)
    logging.info("Division successful!")

except ZeroDivisionError:
    print("Error: Division by zero!")
    logging.error("Division by zero attempted.")
except ValueError:
    print("Error: Invalid input!")
    logging.error("Invalid input value.")
# Out:
# Enter numerator: 10
# Enter denominator: 0
# Error: Division by zero!

# %% [markdown]
# ![Screenshot (38).png](data:image/png;base64,...)

# %% [markdown]
# Q15. Write a Python program that prints the content of a file and handles the case when the file is empty.

# %%
try:
    with open("source.txt", "r") as file:
        content = file.read()
        if content.strip() == "":
            print("The file is empty.")
        else:
            print("File Content:\n", content)
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# File Content:
#  Lara Croft: Tomb Raider
# Sahara
# The Jewel of the Nile
# The Da Vinci Code
# Night at the Museum
# Angels and Demons
# The Goonies
# Indiana Jones and the Temple of Doom
# Raiders of the Lost Ark
# Romancing the Stone
# Blood and Treasure
# Knight and Day

# %% [markdown]
# Q16. Demonstrate how to use memory profiling to check the memory usage of a small program.

# %%
# !pip install memory_profiler psutil

# %%
from memory_profiler import memory_usage

def test():
    nums = [i for i in range(100000)]   # creates a list of 1 lakh numbers
    squares = [n**2 for n in nums]      # creates another list
    return sum(squares)

# Measure memory usage while running the function
mem_usage = memory_usage((test, ))

print("Memory usage samples (in MB):", mem_usage)
print("Peak memory used (in MB):", max(mem_usage))
# Out:
# Memory usage samples (in MB): [107.93359375, 107.93359375, 107.93359375, 107.93359375, 107.93359375, 107.93359375, 107.93359375, 107.93359375, 107.93359375, 108.28515625, 108.734375, 109.203125, 109.67578125, 109.90234375, 109.90234375, 109.90234375, 107.93359375, 107.93359375]
# Peak memory used (in MB): 109.90234375

# %% [markdown]
# Q17.  Write a Python program to create and write a list of numbers to a file, one number per line.

# %%
numbers = [10, 20, 30, 40, 50]

with open("numbers.txt", "w") as file:
    for num in numbers:
        file.write(str(num) + "\n")

print("Numbers written to file successfully!")
# Out:
# Numbers written to file successfully!

# %% [markdown]
# ![Screenshot (39).png](data:image/png;base64,...)

# %% [markdown]
# Q18. How would you implement a basic logging setup that logs to a file with rotation after 1MB.

# %%
import logging
from logging.handlers import RotatingFileHandler

def setup_logging():
    logger = logging.getLogger("app")
    logger.setLevel(logging.INFO)

    # Rotate file after 1MB, keep 5 backups
    handler = RotatingFileHandler(
        "app.log",
        maxBytes=1 * 1024 * 1024,     # 1MB
        backupCount=5,
        encoding="utf-8"
    )

    formatter = logging.Formatter(
        "%(asctime)s - %(levelname)s - %(message)s"
    )
    handler.setFormatter(formatter)

    # Avoid duplicate handlers
    if not logger.handlers:
        logger.addHandler(handler)

    return logger

# Usage
logger = setup_logging()
logger.info("This is an info message")
logger.error("This is an error message")
# Out:
# INFO:app:This is an info message
# ERROR:app:This is an error message

# %% [markdown]
# Q19. Write a program that handles both IndexError and KeyError using a try-except block.

# %%
numbers = [10, 20, 30]
data = {"name": "Dhruv"}

try:
    print(numbers[5])
except IndexError:
    print("Error: Index is out of range!")

try:
    print(data["age"])
except KeyError:
    print("Error: The key does not exist in the dictionary!")
# Out:
# Error: Index is out of range!
# Error: The key does not exist in the dictionary!

# %% [markdown]
# Q20.  How would you open a file and read its contents using a context manager in Python.

# %%
with open("source.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Lara Croft: Tomb Raider
# Sahara
# The Jewel of the Nile
# The Da Vinci Code
# Night at the Museum
# Angels and Demons
# The Goonies
# Indiana Jones and the Temple of Doom
# Raiders of the Lost Ark
# Romancing the Stone
# Blood and Treasure
# Knight and Day

# %% [markdown]
# Q21. Write a Python program that reads a file and prints the number of occurrences of a specific word.

# %%
word = "is"

with open("test.txt", "r") as file:
    content = file.read()

count = content.lower().count(word.lower())

print(f"The word '{word}' occurs {count} times in the file.")
# Out:
# The word 'is' occurs 4 times in the file.

# %% [markdown]
# Q22. How can you check if a file is empty before attempting to read its contents.

# %%
#by checking the size of file

import os
filename = "test.txt"
if os.path.getsize(filename) == 0:
    print("The file is empty.")
else:
    with open(filename, "r") as file:
        print(file.read())
# Out:
# Hello this is my first file!
# This is a new line added to the file.

# %% [markdown]
# Q23. Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging, importlib
importlib.reload(logging)

logging.basicConfig(filename="errors.log",
                    level=logging.ERROR,
                    format="%(message)s")

try:
    with open("data.txt", "r") as f:
        print(f.read())

except Exception as e:
    print("File handling error!")
    logging.error(f"Error: {e}")
# Out:
# File handling error!

# %% [markdown]
# ![Screenshot (40).png](data:image/png;base64,...)
